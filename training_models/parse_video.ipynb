# %%
import cv2
import os

# %%
video_path = "../testing/videos/test1.mp4"
output_folder = "frames"

os.makedirs(output_folder, exist_ok=True)

cap = cv2.VideoCapture(video_path)
fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    if frame_count % fps == 0:
        output_path = os.path.join(output_folder, f"frame_{frame_count:04d}.jpg")
        cv2.imwrite(output_path, frame)
    frame_count += 1

cap.release()
print(f"Extracted {frame_count//fps} frames")
# Out:
# Extracted 236 frames

# %%
# !unzip ball_rim_player.zip
# Out:
# Archive:  ball_rim_player.zip
#  extracting: train.txt
#  extracting: data.yaml
#  extracting: labels/train/frame_11859.txt
#  extracting: labels/train/frame_2006.txt
#  extracting: labels/train/frame_4956.txt
#  extracting: labels/train/frame_8673.txt
#  extracting: labels/train/frame_5487.txt
#  extracting: labels/train/frame_3894.txt
#  extracting: labels/train/frame_10502.txt
#  extracting: labels/train/frame_11033.txt
#  extracting: labels/train/frame_9735.txt
#  extracting: labels/train/frame_10797.txt
#  extracting: labels/train/frame_0413.txt
#  extracting: labels/train/frame_4130.txt
#  extracting: labels/train/frame_6549.txt
#  extracting: labels/train/frame_0826.txt
#  extracting: labels/train/frame_8260.txt
#  extracting: labels/train/frame_4543.txt
#  extracting: labels/train/frame_5074.txt
#  extracting: labels/train/frame_1357.txt
#  extracting: labels/train/frame_10915.txt
#  extracting: labels/train/frame_11446.txt
#  extracting: labels/train/frame_9322.txt
#  extracting: labels/train/frame_5605.txt
#  extracting: labels/train/frame_13570.txt
#  extracting: labels/train/frame_6136.txt
#  extracting: labels/train/frame_0000.txt
#  extracting: labels/train/frame_2419.txt
#  extracting: labels/train/frame_10384.txt
#  extracting: labels/train/frame_13039.txt
#  extracting: labels/train/frame_0295.txt
#  extracting: labels/train/frame_2950.txt
#  extracting: labels/train/frame_3481.txt
#  extracting: labels/train/frame_12508.txt
#  extracting: labels/train/frame_12036.txt
#  extracting: labels/train/frame_4897.txt
#  extracting: labels/train/frame_11505.txt
#  extracting: labels/train/frame_5133.txt
#  extracting: labels/train/frame_1416.txt
#  extracting: labels/train/frame_4602.txt
#  extracting: labels/train/frame_4071.txt
#  extracting: labels/train/frame_0354.txt
#  extracting: labels/train/frame_5959.txt
#  extracting: labels/train/frame_3540.txt
#  extracting: labels/train/frame_9676.txt
#  extracting: labels/train/frame_10443.txt
#  extracting: labels/train/frame_3009.txt
#  extracting: labels/train/frame_11387.txt
#  extracting: labels/train/frame_1003.txt
#  extracting: labels/train/frame_7139.txt
#  extracting: labels/train/frame_10856.txt
#  extracting: labels/train/frame_6608.txt
#  extracting: labels/train/frame_0767.txt
#  extracting: labels/train/frame_4484.txt
#  extracting: labels/train/frame_7670.txt
#  extracting: labels/train/frame_1298.txt
#  extracting: labels/train/frame_3953.txt
#  extracting: labels/train/frame_12449.txt
#  extracting: labels/train/frame_10030.txt
#  extracting: labels/train/frame_11918.txt
#  extracting: labels/train/frame_2891.txt
#  extracting: labels/train/frame_1829.txt
#  extracting: labels/train/frame_9263.txt
#  extracting: labels/train/frame_5546.txt
#  extracting: labels/train/frame_8732.txt
#  extracting: labels/train/frame_6077.txt
#  extracting: labels/train/frame_12980.txt
#  extracting: labels/train/frame_7847.txt
#  extracting: labels/train/frame_1711.txt
#  extracting: labels/train/frame_2242.txt
#  extracting: labels/train/frame_8378.txt
#  extracting: labels/train/frame_11800.txt
#  extracting: labels/train/frame_12331.txt
#  extracting: labels/train/frame_8909.txt
#  extracting: labels/train/frame_0118.txt
#  extracting: labels/train/frame_3304.txt
#  extracting: labels/train/frame_13688.txt
#  extracting: labels/train/frame_7021.txt
#  extracting: labels/train/frame_1180.txt
#  extracting: labels/train/frame_3599.txt
#  extracting: labels/train/frame_10207.txt
#  extracting: labels/train/frame_9971.txt
#  extracting: labels/train/frame_6785.txt
#  extracting: labels/train/frame_13806.txt
#  extracting: labels/train/frame_1593.txt
#  extracting: labels/train/frame_6903.txt
#  extracting: labels/train/frame_4248.txt
#  extracting: labels/train/frame_7434.txt
#  extracting: labels/train/frame_3717.txt
#  extracting: labels/train/frame_11682.txt
#  extracting: labels/train/frame_5841.txt
#  extracting: labels/train/frame_3186.txt
#  extracting: labels/train/frame_6372.txt
#  extracting: labels/train/frame_2655.txt
#  extracting: labels/train/frame_9027.txt
#  extracting: labels/train/frame_13275.txt
#  extracting: labels/train/frame_10089.txt
#  extracting: labels/train/frame_12744.txt
#  extracting: labels/train/frame_8024.txt
#  extracting: labels/train/frame_12272.txt
#  extracting: labels/train/frame_4307.txt
#  extracting: labels/train/frame_11741.txt
#  extracting: labels/train/frame_7788.txt
#  extracting: labels/train/frame_1652.txt
#  extracting: labels/train/frame_2183.txt
#  extracting: labels/train/frame_0590.txt
#  extracting: labels/train/frame_13334.txt
#  extracting: labels/train/frame_10148.txt
#  extracting: labels/train/frame_12803.txt
#  extracting: labels/train/frame_6431.txt
#  extracting: labels/train/frame_2714.txt
#  extracting: labels/train/frame_0059.txt
#  extracting: labels/train/frame_5900.txt
#  extracting: labels/train/frame_3245.txt
#  extracting: labels/train/frame_3658.txt
#  extracting: labels/train/frame_7375.txt
#  extracting: labels/train/frame_6844.txt
#  extracting: labels/train/frame_4189.txt
#  extracting: labels/train/frame_13747.txt
#  extracting: labels/train/frame_2301.txt
#  extracting: labels/train/frame_12685.txt
#  extracting: labels/train/frame_8437.txt
#  extracting: labels/train/frame_7906.txt
#  extracting: labels/train/frame_5782.txt
#  extracting: labels/train/frame_2596.txt
#  extracting: labels/train/frame_11977.txt
#  extracting: labels/train/frame_5310.txt
#  extracting: labels/train/frame_7729.txt
#  extracting: labels/train/frame_2124.txt
#  extracting: labels/train/frame_8791.txt
#  extracting: labels/train/frame_12213.txt
#  extracting: labels/train/frame_1888.txt
#  extracting: labels/train/frame_10620.txt
#  extracting: labels/train/frame_11151.txt
#  extracting: labels/train/frame_9853.txt
#  extracting: labels/train/frame_7198.txt
#  extracting: labels/train/frame_1062.txt
#  extracting: labels/train/frame_6667.txt
#  extracting: labels/train/frame_0531.txt
#  extracting: labels/train/frame_4661.txt
#  extracting: labels/train/frame_0944.txt
#  extracting: labels/train/frame_1475.txt
#  extracting: labels/train/frame_5192.txt
#  extracting: labels/train/frame_12095.txt
#  extracting: labels/train/frame_11564.txt
#  extracting: labels/train/frame_7316.txt
#  extracting: labels/train/frame_5723.txt
#  extracting: labels/train/frame_3068.txt
#  extracting: labels/train/frame_9440.txt
#  extracting: labels/train/frame_2537.txt
#  extracting: labels/train/frame_6254.txt
#  extracting: labels/train/frame_13157.txt
#  extracting: labels/train/frame_12626.txt
#  extracting: labels/train/frame_12154.txt
#  extracting: labels/train/frame_11623.txt
#  extracting: labels/train/frame_1534.txt
#  extracting: labels/train/frame_5251.txt
#  extracting: labels/train/frame_4720.txt
#  extracting: labels/train/frame_2065.txt
#  extracting: labels/train/frame_13216.txt
#  extracting: labels/train/frame_0472.txt
#  extracting: labels/train/frame_9794.txt
#  extracting: labels/train/frame_10561.txt
#  extracting: labels/train/frame_6313.txt
#  extracting: labels/train/frame_11092.txt
#  extracting: labels/train/frame_3127.txt
#  extracting: labels/train/frame_9912.txt
#  extracting: labels/train/frame_7257.txt
#  extracting: labels/train/frame_1121.txt
#  extracting: labels/train/frame_6726.txt
#  extracting: labels/train/frame_10974.txt
#  extracting: labels/train/frame_11210.txt
#  extracting: labels/train/frame_13629.txt
#  extracting: labels/train/frame_0885.txt
#  extracting: labels/train/frame_8319.txt
#  extracting: labels/train/frame_12567.txt
#  extracting: labels/train/frame_13098.txt
#  extracting: labels/train/frame_5664.txt
#  extracting: labels/train/frame_9381.txt
#  extracting: labels/train/frame_1947.txt
#  extracting: labels/train/frame_2478.txt
#  extracting: labels/train/frame_8850.txt
#  extracting: labels/train/frame_6195.txt
#  extracting: labels/train/frame_7965.txt
#  extracting: labels/train/frame_8496.txt
#  extracting: labels/train/frame_4779.txt
#  extracting: labels/train/frame_2360.txt
#  extracting: labels/train/frame_5015.txt
#  extracting: labels/train/frame_8201.txt
#  extracting: labels/train/frame_0236.txt
#  extracting: labels/train/frame_9558.txt
#  extracting: labels/train/frame_3422.txt
#  extracting: labels/train/frame_10325.txt
#  extracting: labels/train/frame_13511.txt
#  extracting: labels/train/frame_11269.txt
#  extracting: labels/train/frame_13924.txt
#  extracting: labels/train/frame_10738.txt
#  extracting: labels/train/frame_4366.txt
#  extracting: labels/train/frame_0649.txt
#  extracting: labels/train/frame_8083.txt
#  extracting: labels/train/frame_3835.txt
#  extracting: labels/train/frame_7552.txt
#  extracting: labels/train/frame_2773.txt
#  extracting: labels/train/frame_6490.txt
#  extracting: labels/train/frame_13393.txt
#  extracting: labels/train/frame_5428.txt
#  extracting: labels/train/frame_9145.txt
#  extracting: labels/train/frame_12862.txt
#  extracting: labels/train/frame_8614.txt
#  extracting: labels/train/frame_12390.txt
#  extracting: labels/train/frame_4425.txt
#  extracting: labels/train/frame_0708.txt
#  extracting: labels/train/frame_8142.txt
#  extracting: labels/train/frame_1239.txt
#  extracting: labels/train/frame_7611.txt
#  extracting: labels/train/frame_1770.txt
#  extracting: labels/train/frame_11328.txt
#  extracting: labels/train/frame_13452.txt
#  extracting: labels/train/frame_9204.txt
#  extracting: labels/train/frame_10266.txt
#  extracting: labels/train/frame_12921.txt
#  extracting: labels/train/frame_6018.txt
#  extracting: labels/train/frame_2832.txt
#  extracting: labels/train/frame_0177.txt
#  extracting: labels/train/frame_8968.txt
#  extracting: labels/train/frame_9499.txt
#  extracting: labels/train/frame_7080.txt
#  extracting: labels/train/frame_3363.txt
#  extracting: labels/train/frame_7493.txt
#  extracting: labels/train/frame_3776.txt
#  extracting: labels/train/frame_6962.txt
#  extracting: labels/train/frame_9617.txt
#  extracting: labels/train/frame_13865.txt
#  extracting: labels/train/frame_4012.txt
#  extracting: labels/train/frame_10679.txt
#  extracting: labels/train/frame_8555.txt
#  extracting: labels/train/frame_4838.txt
#  extracting: labels/train/frame_5369.txt
#  extracting: labels/train/frame_9086.txt
